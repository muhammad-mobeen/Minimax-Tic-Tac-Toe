# %% [markdown]
# <h1 align="center">Title: Minimax Algorithm for Tic Tac Toe</h1>
# <p>Name: Muhammad Mobeen<br>
# Reg No: 200901097<br>
# BS-CS-01(B)<br>
# Artificial Intelligence Assignment No 2<br>
# Github URL: <a href="https://github.com/muhammad-mobeen/Minimax-Tic-Tac-Toe">github.com/muhammad-mobeen/Minimax-Tic-Tac-Toe</a><br>
# Submitted to Mam Reeda Saeed</p>

# %%
def printBoard(board):
    '''The printBoard function takes the board data structure and prints it to the console in the form of a Tic-Tac-Toe board.'''
    print(board[1] + '|' + board[2] + '|' + board[3])
    print('-+-+-')
    print(board[4] + '|' + board[5] + '|' + board[6])
    print('-+-+-')
    print(board[7] + '|' + board[8] + '|' + board[9])
    print("\n")


def spaceIsFree(position):
    '''
    The spaceIsFree function takes a position on the board and returns True if that position is empty, or False if it is already occupied.
    '''
    if board[position] == ' ':
        return True
    else:
        return False


def insertLetter(letter, position):
    '''
    The insertLetter function takes a letter (either 'X' or 'O') and a position on the board. If the position is free, it inserts the letter into that position and prints the updated board. If the board is now in a winning or draw state, it prints a message indicating the result and exits the program. If the position is not free, it prompts the user to enter a new position until a valid position is entered.
    '''
    if spaceIsFree(position):
        board[position] = letter
        printBoard(board)
        if (checkDraw()):
            print("Draw!")
            exit()
        if checkForWin():
            if letter == 'X':
                print("Bot wins!")
                exit()
            else:
                print("Player wins!")
                exit()
        return
    else:
        print("Can't insert there!")
        position = int(input("Please enter new position:  "))
        insertLetter(letter, position)
        return


def checkForWin():
    '''
    The checkForWin function checks the current state of the board and returns True if there is a winner, or False otherwise.
    '''
    if (board[1] == board[2] and board[1] == board[3] and board[1] != ' '):
        return True
    elif (board[4] == board[5] and board[4] == board[6] and board[4] != ' '):
        return True
    elif (board[7] == board[8] and board[7] == board[9] and board[7] != ' '):
        return True
    elif (board[1] == board[4] and board[1] == board[7] and board[1] != ' '):
        return True
    elif (board[2] == board[5] and board[2] == board[8] and board[2] != ' '):
        return True
    elif (board[3] == board[6] and board[3] == board[9] and board[3] != ' '):
        return True
    elif (board[1] == board[5] and board[1] == board[9] and board[1] != ' '):
        return True
    elif (board[7] == board[5] and board[7] == board[3] and board[7] != ' '):
        return True
    else:
        return False


def checkWhichMarkWon(mark):
    '''
    The checkWhichMarkWon function is similar to checkForWin, but it takes an argument mark (either 'X' or 'O') and returns True if that mark has won, or False otherwise.
    '''
    if board[1] == board[2] and board[1] == board[3] and board[1] == mark:
        return True
    elif (board[4] == board[5] and board[4] == board[6] and board[4] == mark):
        return True
    elif (board[7] == board[8] and board[7] == board[9] and board[7] == mark):
        return True
    elif (board[1] == board[4] and board[1] == board[7] and board[1] == mark):
        return True
    elif (board[2] == board[5] and board[2] == board[8] and board[2] == mark):
        return True
    elif (board[3] == board[6] and board[3] == board[9] and board[3] == mark):
        return True
    elif (board[1] == board[5] and board[1] == board[9] and board[1] == mark):
        return True
    elif (board[7] == board[5] and board[7] == board[3] and board[7] == mark):
        return True
    else:
        return False


def checkDraw():
    '''
    The checkDraw function checks the current state of the board and returns True if the game has ended in a draw, or False otherwise.
    '''
    for key in board.keys():
        if (board[key] == ' '):
            return False
    return True


def playerMove():
    '''
    The playerMove function prompts the user to enter a position on the board for their move, and then calls insertLetter with the 'O' mark and the chosen position.
    '''
    position = int(input("Enter the position for 'O':  "))
    insertLetter(player, position)
    return


def compMove():
    '''
    The compMove function is responsible for the computer's move. It uses the minimax algorithm to search for the best move, and then calls insertLetter with the 'X' mark and the chosen position.
    '''
    bestScore = -800
    bestMove = 0
    for key in board.keys():
        if (board[key] == ' '):
            board[key] = bot
            score = minimax(board, 0, False)
            board[key] = ' '
            if (score > bestScore):
                bestScore = score
                bestMove = key

    insertLetter(bot, bestMove)
    return


def minimax(board, depth, isMaximizing):
    '''
    The minimax function is the implementation of the minimax algorithm. It takes the current state of the board, the current depth of the search, and a boolean indicating whether it is maximizing or minimizing. It returns a score indicating the best move for the current player.
    '''
    if (checkWhichMarkWon(bot)):
        return 1
    elif (checkWhichMarkWon(player)):
        return -1
    elif (checkDraw()):
        return 0

    if (isMaximizing):
        bestScore = -800
        for key in board.keys():
            if (board[key] == ' '):
                board[key] = bot
                score = minimax(board, depth + 1, False)
                board[key] = ' '
                if (score > bestScore):
                    bestScore = score
        return bestScore

    else:
        bestScore = 800
        for key in board.keys():
            if (board[key] == ' '):
                board[key] = player
                score = minimax(board, depth + 1, True)
                board[key] = ' '
                if (score < bestScore):
                    bestScore = score
        return bestScore


board = {1: ' ', 2: ' ', 3: ' ',
         4: ' ', 5: ' ', 6: ' ',
         7: ' ', 8: ' ', 9: ' '}

printBoard(board)
print("Computer goes first! Good luck.")
print("Positions are as follow:")
print("1, 2, 3 ")
print("4, 5, 6 ")
print("7, 8, 9 ")
print("\n")
player = 'O'
bot = 'X'


global firstComputerMove
firstComputerMove = True

while not checkForWin():
    compMove()
    playerMove()
